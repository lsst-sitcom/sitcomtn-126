# %%
import sys, time, os, asyncio, warnings
from datetime import datetime
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
# %matplotlib inline
from astropy.time import Time, TimeDelta
from lsst.daf.butler import Butler
from lsst_efd_client import EfdClient
from lsst.summit.utils import dayObsIntToString
from lsst.summit.utils.efdUtils import calcNextDay
from lsst.summit.extras.rubinTvDatabase import getRubinTvDatabase
# This needs tickets/DM-42894 for summit_extras

# %%
client = EfdClient('usdf_efd')
butler = Butler('/repo/embargo', collections="LATISS/raw/all")

# %% [markdown]
# # Get the classified mount error data from 2023

# %%
infile = open('/home/c/cslage/u/AuxTel/mount_classifier/Mount_Errors_Classified_Dict_29Dec23.pkl', 'rb')
Mount_Errors_Classified_Dict = pkl.load(infile)
infile.close()

# %% [markdown]
# # Get the RubinTV json data

# %%
json_data = getRubinTvDatabase('LATISS')
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">root</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: WARNING - This interface will disappear as soon as we have a visit database! This is a temporary convenience *only* - DO NOT build software which relies on this!</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">/home/a/ashugart/WORK/summit_extras/python/lsst/summit/extras/rubinTvDatabase.py</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: WARNING - This interface will disappear as soon as we have a visit database! This is a temporary convenience *only* - DO NOT build software which relies on this!</pre>

# %% [markdown]
# # Now walk thru 2023, getting the wind induced failures and the wind speed data

# %%
wind_speeds = []
image_degs = []
image_dirs = []
els = []
azs = []
wind_directions = []

startDay = 20230101
endDay = 20231231

dayObs = startDay
while dayObs < endDay:
    # Don't do the dayObs if there is no wind data.
    nextDayObs = calcNextDay(dayObs)
    start = Time(f"{dayObsIntToString(dayObs)} 23:00:00Z", scale='utc')
    end = Time(f"{dayObsIntToString(nextDayObs)} 08:00:00Z", scale='utc')
    maxSpeed = await client.select_time_series('lsst.sal.ESS.airFlow', \
                                                ['maxSpeed'],  start, end, index=301)
    if len(maxSpeed) == 0:
        print(f"No wind data for {dayObs}")
        dayObs = calcNextDay(dayObs)
        continue

    this_rubintv = json_data[json_data['dayObs'] == dayObs]
    seqNums = this_rubintv['seqNum'].values
    counter = 0
    for seqNum in seqNums:
        try:
            if seqNum in Mount_Errors_Classified_Dict[dayObs]['OSC']:
                continue
            if seqNum in Mount_Errors_Classified_Dict[dayObs]['TIM']:
                continue
        except:
            pass
        # Get the image degradation from RubinTV
        seqNum_rubintv = this_rubintv[this_rubintv['seqNum'] == seqNum]
        try:
            image_deg = seqNum_rubintv['Mount motion image degradation'].values[0]
            if np.isnan(image_deg):
                continue
            # Get the other data from the butler
            expId = dayObs * 100000 + seqNum
            dataId = {'detector':0, 'exposure':expId}
            mData = butler.get('raw.metadata', dataId=dataId)
            tStart = mData['DATE-BEG']
            start = Time(tStart, scale='tai').utc
            tEnd = mData['DATE-END']
            end = Time(tEnd, scale='tai').utc
            az = mData['AZSTART']
            el = mData['ELSTART']
            wind_data = await client.select_time_series('lsst.sal.ESS.airFlow', \
                                                    ['maxSpeed','direction'],  start, end, index=301)
            if len(wind_data) == 0:
                # Checks to make sure wind data is there
                continue
        except:
            continue
        wind_speed = np.median(wind_data.values[:,0])
        wind_dir = np.median(wind_data.values[:,1])
        image_dir = (wind_dir - az) 
        # This is the angle between the 
        # wind and the telescope pointing
        els.append(el)
        azs.append(az)
        wind_directions.append(wind_dir)
        image_degs.append(image_deg)
        wind_speeds.append(wind_speed)
        image_dirs.append(image_dir)
        counter += 1
        #print(expId, image_deg, wind_speed, wind_dir, az, image_dir)  
    print(f"Finished {dayObs}, with {counter} good values")
    dayObs = calcNextDay(dayObs)
# Out:
# No wind data for 20230101
# No wind data for 20230102
# No wind data for 20230103
# No wind data for 20230104
# No wind data for 20230105
# No wind data for 20230106
# No wind data for 20230107
# No wind data for 20230108
# No wind data for 20230109
# No wind data for 20230110
# No wind data for 20230111
# No wind data for 20230112
# No wind data for 20230113
# No wind data for 20230114
# No wind data for 20230115
# No wind data for 20230116
# No wind data for 20230117
# No wind data for 20230118
# No wind data for 20230119
# No wind data for 20230120
# No wind data for 20230121
# No wind data for 20230122
# No wind data for 20230123
# No wind data for 20230124
# No wind data for 20230125
# No wind data for 20230126
# No wind data for 20230127
# No wind data for 20230128
# No wind data for 20230129
# No wind data for 20230130
# No wind data for 20230131
# No wind data for 20230201
# No wind data for 20230202
# No wind data for 20230203
# No wind data for 20230204
# No wind data for 20230205
# No wind data for 20230206
# No wind data for 20230207
# No wind data for 20230208
# No wind data for 20230209
# No wind data for 20230210
# No wind data for 20230211
# No wind data for 20230212
# No wind data for 20230213
# No wind data for 20230214
# No wind data for 20230215
# No wind data for 20230216
# No wind data for 20230217
# No wind data for 20230218
# No wind data for 20230219
# No wind data for 20230220
# No wind data for 20230221
# No wind data for 20230222
# No wind data for 20230223
# No wind data for 20230224
# No wind data for 20230225
# No wind data for 20230226
# No wind data for 20230227
# No wind data for 20230228
# No wind data for 20230301
# No wind data for 20230302
# No wind data for 20230303
# No wind data for 20230304
# No wind data for 20230305
# No wind data for 20230306
# No wind data for 20230307
# No wind data for 20230308
# No wind data for 20230309
# No wind data for 20230310
# No wind data for 20230311
# No wind data for 20230312
# No wind data for 20230313
# No wind data for 20230314
# Finished 20230315, with 688 good values
# Finished 20230316, with 620 good values
# No wind data for 20230317
# No wind data for 20230318
# No wind data for 20230319
# Finished 20230320, with 0 good values
# Finished 20230321, with 41 good values
# Finished 20230322, with 0 good values
# Finished 20230323, with 0 good values
# Finished 20230324, with 0 good values
# Finished 20230325, with 0 good values
# Finished 20230326, with 0 good values
# Finished 20230327, with 0 good values
# Finished 20230328, with 0 good values
# Finished 20230329, with 0 good values
# Finished 20230330, with 0 good values
# Finished 20230331, with 0 good values
# Finished 20230401, with 0 good values
# Finished 20230402, with 0 good values
# Finished 20230403, with 0 good values
# Finished 20230404, with 81 good values
# No wind data for 20230405
# Finished 20230406, with 0 good values
# Finished 20230407, with 0 good values
# Finished 20230408, with 0 good values
# Finished 20230409, with 0 good values
# Finished 20230410, with 0 good values
# Finished 20230411, with 91 good values
# Finished 20230412, with 0 good values
# Finished 20230413, with 113 good values
# Finished 20230414, with 0 good values
# Finished 20230415, with 0 good values
# Finished 20230416, with 0 good values
# Finished 20230417, with 0 good values
# Finished 20230418, with 0 good values
# Finished 20230419, with 0 good values
# Finished 20230420, with 167 good values
# Finished 20230421, with 0 good values
# Finished 20230422, with 0 good values
# Finished 20230423, with 0 good values
# Finished 20230424, with 0 good values
# Finished 20230425, with 110 good values
# Finished 20230426, with 0 good values
# Finished 20230427, with 21 good values
# Finished 20230428, with 0 good values
# Finished 20230429, with 0 good values
# Finished 20230430, with 0 good values
# Finished 20230501, with 0 good values
# Finished 20230502, with 0 good values
# Finished 20230503, with 0 good values
# Finished 20230504, with 0 good values
# Finished 20230505, with 0 good values
# Finished 20230506, with 0 good values
# Finished 20230507, with 0 good values
# No wind data for 20230508
# No wind data for 20230509
# No wind data for 20230510
# No wind data for 20230511
# No wind data for 20230512
# No wind data for 20230513
# Finished 20230514, with 0 good values
# Finished 20230515, with 0 good values
# Finished 20230516, with 0 good values
# Finished 20230517, with 0 good values
# Finished 20230518, with 0 good values
# Finished 20230519, with 0 good values
# Finished 20230520, with 0 good values
# Finished 20230521, with 0 good values
# Finished 20230522, with 0 good values
# Finished 20230523, with 364 good values
# Finished 20230524, with 429 good values
# Finished 20230525, with 34 good values
# Finished 20230526, with 0 good values
# Finished 20230527, with 0 good values
# Finished 20230528, with 0 good values
# Finished 20230529, with 0 good values
# Finished 20230530, with 0 good values
# Finished 20230531, with 0 good values
# Finished 20230601, with 0 good values
# No wind data for 20230602
# No wind data for 20230603
# No wind data for 20230604
# No wind data for 20230605
# No wind data for 20230606
# No wind data for 20230607
# No wind data for 20230608
# No wind data for 20230609
# No wind data for 20230610
# No wind data for 20230611
# No wind data for 20230612
# Finished 20230613, with 0 good values
# Finished 20230614, with 0 good values
# Finished 20230615, with 0 good values
# Finished 20230616, with 0 good values
# Finished 20230617, with 0 good values
# Finished 20230618, with 0 good values
# Finished 20230619, with 0 good values
# Finished 20230620, with 0 good values
# Finished 20230621, with 0 good values
# Finished 20230622, with 0 good values
# Finished 20230623, with 0 good values
# Finished 20230624, with 0 good values
# Finished 20230625, with 0 good values
# Finished 20230626, with 0 good values
# Finished 20230627, with 0 good values
# Finished 20230628, with 0 good values
# Finished 20230629, with 0 good values
# Finished 20230630, with 0 good values
# Finished 20230701, with 0 good values
# Finished 20230702, with 0 good values
# Finished 20230703, with 0 good values
# Finished 20230704, with 265 good values
# Finished 20230705, with 161 good values
# Finished 20230706, with 392 good values
# Finished 20230707, with 0 good values
# Finished 20230708, with 0 good values
# Finished 20230709, with 0 good values
# Finished 20230710, with 0 good values
# Finished 20230711, with 0 good values
# Finished 20230712, with 0 good values
# Finished 20230713, with 0 good values
# Finished 20230714, with 0 good values
# Finished 20230715, with 0 good values
# Finished 20230716, with 0 good values
# Finished 20230717, with 1 good values
# Finished 20230718, with 132 good values
# Finished 20230719, with 0 good values
# Finished 20230720, with 226 good values
# No wind data for 20230721
# No wind data for 20230722
# No wind data for 20230723
# Finished 20230724, with 0 good values
# Finished 20230725, with 1 good values
# Finished 20230726, with 0 good values
# Finished 20230727, with 0 good values
# Finished 20230728, with 0 good values
# Finished 20230729, with 0 good values
# Finished 20230730, with 0 good values
# Finished 20230731, with 0 good values
# Finished 20230801, with 128 good values
# Finished 20230802, with 264 good values
# Finished 20230803, with 431 good values
# Finished 20230804, with 0 good values
# Finished 20230805, with 0 good values
# Finished 20230806, with 0 good values
# Finished 20230807, with 0 good values
# Finished 20230808, with 0 good values
# Finished 20230809, with 0 good values
# Finished 20230810, with 0 good values
# Finished 20230811, with 0 good values
# Finished 20230812, with 0 good values
# Finished 20230813, with 0 good values
# Finished 20230814, with 0 good values
# Finished 20230815, with 61 good values
# Finished 20230816, with 54 good values
# Finished 20230817, with 321 good values
# No wind data for 20230818
# No wind data for 20230819
# No wind data for 20230820
# Finished 20230821, with 0 good values
# Finished 20230822, with 0 good values
# Finished 20230823, with 0 good values
# Finished 20230824, with 3 good values
# Finished 20230825, with 0 good values
# Finished 20230826, with 0 good values
# Finished 20230827, with 0 good values
# Finished 20230828, with 0 good values
# Finished 20230829, with 305 good values
# Finished 20230830, with 0 good values
# No wind data for 20230831
# No wind data for 20230901
# No wind data for 20230902
# No wind data for 20230903
# No wind data for 20230904
# Finished 20230905, with 0 good values
# Finished 20230906, with 0 good values
# Finished 20230907, with 3 good values
# Finished 20230908, with 0 good values
# Finished 20230909, with 0 good values
# Finished 20230910, with 0 good values
# Finished 20230911, with 0 good values
# Finished 20230912, with 246 good values
# Finished 20230913, with 186 good values
# Finished 20230914, with 214 good values
# Finished 20230915, with 0 good values
# Finished 20230916, with 0 good values
# Finished 20230917, with 0 good values
# Finished 20230918, with 0 good values
# Finished 20230919, with 0 good values
# Finished 20230920, with 0 good values
# Finished 20230921, with 263 good values
# Finished 20230922, with 223 good values
# Finished 20230923, with 0 good values
# Finished 20230924, with 0 good values
# Finished 20230925, with 0 good values
# Finished 20230926, with 361 good values
# Finished 20230927, with 218 good values
# Finished 20230928, with 297 good values
# Finished 20230929, with 0 good values
# Finished 20230930, with 0 good values
# Finished 20231001, with 0 good values
# Finished 20231002, with 0 good values
# Finished 20231003, with 0 good values
# Finished 20231004, with 0 good values
# Finished 20231005, with 0 good values
# Finished 20231006, with 0 good values
# Finished 20231007, with 0 good values
# Finished 20231008, with 0 good values
# Finished 20231009, with 0 good values
# Finished 20231010, with 343 good values
# Finished 20231011, with 27 good values
# Finished 20231012, with 0 good values
# No wind data for 20231013
# No wind data for 20231014
# No wind data for 20231015
# No wind data for 20231016
# Finished 20231017, with 0 good values
# Finished 20231018, with 0 good values
# Finished 20231019, with 0 good values
# Finished 20231020, with 0 good values
# Finished 20231021, with 0 good values
# Finished 20231022, with 0 good values
# Finished 20231023, with 0 good values
# Finished 20231024, with 0 good values
# Finished 20231025, with 0 good values
# Finished 20231026, with 0 good values
# Finished 20231027, with 0 good values
# Finished 20231028, with 0 good values
# Finished 20231029, with 0 good values
# Finished 20231030, with 0 good values
# Finished 20231031, with 0 good values
# Finished 20231101, with 0 good values
# Finished 20231102, with 0 good values
# Finished 20231103, with 0 good values
# Finished 20231104, with 0 good values
# Finished 20231105, with 0 good values
# Finished 20231106, with 0 good values
# Finished 20231107, with 261 good values
# Finished 20231108, with 147 good values
# Finished 20231109, with 0 good values
# Finished 20231110, with 0 good values
# Finished 20231111, with 0 good values
# Finished 20231112, with 0 good values
# Finished 20231113, with 153 good values
# Finished 20231114, with 163 good values
# Finished 20231115, with 246 good values
# Finished 20231116, with 428 good values
# Finished 20231117, with 0 good values
# Finished 20231118, with 0 good values
# Finished 20231119, with 0 good values
# Finished 20231120, with 333 good values
# Finished 20231121, with 386 good values
# Finished 20231122, with 0 good values
# Finished 20231123, with 0 good values
# Finished 20231124, with 0 good values
# Finished 20231125, with 0 good values
# Finished 20231126, with 0 good values
# Finished 20231127, with 325 good values
# Finished 20231128, with 316 good values
# Finished 20231129, with 315 good values
# Finished 20231130, with 297 good values
# Finished 20231201, with 0 good values
# Finished 20231202, with 0 good values
# Finished 20231203, with 0 good values
# Finished 20231204, with 300 good values
# Finished 20231205, with 241 good values
# Finished 20231206, with 264 good values
# Finished 20231207, with 152 good values
# Finished 20231208, with 0 good values
# Finished 20231209, with 0 good values
# Finished 20231210, with 0 good values
# Finished 20231211, with 298 good values
# Finished 20231212, with 319 good values
# Finished 20231213, with 0 good values
# Finished 20231214, with 269 good values
# Finished 20231215, with 262 good values
# Finished 20231216, with 0 good values
# Finished 20231217, with 0 good values
# Finished 20231218, with 20 good values
# Finished 20231219, with 280 good values
# Finished 20231220, with 287 good values
# Finished 20231221, with 297 good values
# Finished 20231222, with 299 good values
# Finished 20231223, with 0 good values
# Finished 20231224, with 0 good values
# Finished 20231225, with 0 good values
# Finished 20231226, with 0 good values
# Finished 20231227, with 0 good values
# Finished 20231228, with 0 good values
# Finished 20231229, with 0 good values
# Finished 20231230, with 0 good values

# %%
len(wind_speeds)

# %% [markdown]
# # Bin the data by wind speed to eliminate the noise

# %%
# %matplotlib inline
plot_speeds = []
plot_degs = []
yerr = []
speed_step = 1
for speed in range(0,16,speed_step):
    speed_min = speed
    speed_max = speed + speed_step
    degs = []
    for i in range(len(wind_speeds)):
        if wind_speeds[i] > speed_min and wind_speeds[i] < speed_max:
            deg = image_degs[i]
            if deg < 2.0:
                degs.append(image_degs[i])
    plot_speeds.append(speed + speed_step / 2.0)
    plot_degs.append(np.median(degs))
    yerr.append(np.std(degs) / np.sqrt(len(degs)))
plt.errorbar(plot_speeds, plot_degs, yerr=yerr, marker = 'x')
plt.xlabel("Wind speed (m/s)")
plt.ylabel("Median mount motion image degradation (arcseconds)")
plt.ylim(0,0.5)

# %% [markdown]
# # Now try binning by angle

# %%
# %matplotlib inline
speed_step = 2
dirs = [[-10, 10, 'blue'], [170, 190, 'red'], [80, 100, 'green']]
for [dir_min, dir_max, color] in dirs:
    plot_speeds = []
    plot_degs = []
    yerr = []

    for speed in range(0,16,speed_step):
        speed_min = speed
        speed_max = speed + speed_step
        degs = []
        for i in range(len(wind_speeds)):
            if wind_speeds[i] > speed_min and wind_speeds[i] < speed_max \
            and ((image_dirs[i] > dir_min and image_dirs[i] < dir_max) \
            or (image_dirs[i] < -dir_min and image_dirs[i] < -dir_max)):
                deg = image_degs[i]
                if deg < 2.0:
                    degs.append(image_degs[i])
        plot_speeds.append(speed + speed_step / 2.0)
        plot_degs.append(np.median(degs))
        yerr.append(np.std(degs) / np.sqrt(len(degs)))
        #print(dir_min, speed_min, len(degs))
    plt.errorbar(plot_speeds, plot_degs, yerr=yerr, marker = 'x', color=color, label=str(dir_min+10))
plt.xlabel("Wind speed (m/s)")
plt.ylabel("Median mount motion image degradation (arcseconds)")
plt.ylim(0,0.5)
plt.legend()

# %%
plt.hist(image_dirs)

# %%
# %matplotlib inline
plot_speeds = []
plot_degs = []
for i in range(len(wind_speeds)):
    #if wind_directions[i] > 160.0 and wind_directions[i] < 200.0:
    plot_speeds.append(wind_speeds[i])
    plot_degs.append(image_degs[i])
plt.scatter(plot_speeds, plot_degs)
plt.xlabel("Wind speed (m/s)")
plt.ylabel("Mount motion image degradation (arcseconds)")
plt.ylim(0,1.0)
